# %%
import pandas as pd
import numpy as np
import os
import json
from datetime import datetime

# %%
def _create_dataframes_from_json (json_x, idx):
    '''Return a dataframe from the json file (the idx is only important for the next function)'''

    # It is important to set the working directory to the correct path

    # Import modules
    import numpy as np
    import pandas as pd
    import json

    # Load JSON and create dictionary json_data
    with open(json_x) as json_file:
        json_data = json.load(json_file)

    # Get list of dictionaries with the corresponding x,y-pairs and time
    events_lt = json_data.get('events')

    # Create dataframe from list of dictionaries
    events_df = pd.DataFrame(events_lt)

    # Get dictionary with the information of the session
    session_dc = json_data.get('session')

    # Create dataframe from dictionary (with one row) (session data)
    session_df_temp = pd.DataFrame.from_dict(session_dc, orient ='index')
    session_df_temp = session_df_temp.transpose()

    # Create dataframe with number of rows corresponding to events_df
    session_df = session_df_temp.append([session_df_temp]*(events_df.x.count()-1),ignore_index=True)

    # Get the first rows of the json file in a dictionary
    beg_dc = dict((k, json_data[k]) for k in ('startTime', 'websitePageUrl', 'visitTime',"engagementTime", "pageTitle", "url", 
                                       "viewportWidth", "viewportHeight", "tags"))

    # Create dataframe from dictionary (with one row) (data of first rows)
    beg_df_temp = pd.DataFrame.from_dict(beg_dc, orient = 'index').T

    # Create dataframe with number of rows corresponding to events_df
    beg_df = beg_df_temp.append([beg_df_temp]*(events_df.x.count()-1),ignore_index=True)

    # Concatenate all three dataframes into one
    df = pd.concat([ beg_df, events_df, session_df],axis=1)
    
    # Add index column (for further function)
    df.insert(loc=0,column='idx', value = idx)
    
    # Check if 'ta' column exists
    if 'ta' not in df.columns:
        df.insert(loc=12,column='ta', value = np.NaN)
        
    # Check if 'v' column exists
    if 'v' in df.columns:
        del df['v']

    # Return dataframe
    return df

# %%
def _create_dataframe_from_files(work_dir):
    '''This function takes the working directory as an input, uses the function '_create_dataframes_from_json' to 
    transform the json files into dataframes and returns a 'big' dataframe where the single dataframes of each file 
    are concatenated'''
    
    # Return list of files in working directory
    list_dir = os.listdir(work_dir)
    
    # Initialize dataframe with all files
    df_total = pd.DataFrame(columns=['idx', 'startTime', 'websitePageUrl', 'visitTime', 'engagementTime',
       'pageTitle', 'url', 'viewportWidth', 'viewportHeight', 'tags', 'e', 't',
       'ta', 'ty', 'x', 'y', 'id', 'created', 'lastActivity', 'pages',
       'duration', 'engagementTime', 'totalFriction', 'country', 'region',
       'city', 'isp', 'ip', 'lang', 'userAgent', 'browser', 'browserVersion',
       'os', 'osVersion', 'device', 'referrer', 'referrerType', 'screenRes',
       'entryPage', 'tags', 'variables', 'watched', 'starred', 'lng', 'lat',
       'visitorId', 'gdpr', 'visitorName', 'playbackUrl'])
    
    # Loop over every file in the list and return as a dataframe
    for index, file in enumerate(list_dir):
        df_single = _create_dataframes_from_json(file,index)
        
        # Append dataframe of a single file to the dataframe with all files
        df_total = df_total.append(df_single, ignore_index = True)
        
    col = ['idx','startTime', 'websitePageUrl', 'visitTime', 'engagementTime1',
    'pageTitle', 'url', 'viewportWidth', 'viewportHeight', 'tags1', 'e', 't',
    'ta', 'ty', 'x', 'y', 'id', 'created', 'lastActivity', 'pages',
    'duration', 'engagementTime2', 'totalFriction', 'country', 'region',
    'city', 'isp', 'ip', 'lang', 'userAgent', 'browser', 'browserVersion',
    'os', 'osVersion', 'device', 'referrer', 'referrerType', 'screenRes',
    'entryPage', 'tags2', 'variables', 'watched', 'starred', 'lng', 'lat',
    'visitorId', 'gdpr', 'visitorName', 'playbackUrl']
    
    df_total.columns = col
    
    # Return dataframe
    return(df_total)

# %%
direction = r'C:\Users\Sellit\Desktop\BA_Coding\Data\test9001'

# %%
os.chdir(direction)

# %%
start=datetime.now()
df_test = _create_dataframe_from_files(direction)
end = datetime.now()
print(end - start)
# Out:
# 0:00:00.076703

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60552 entries, 0 to 60551
# Data columns (total 49 columns):
# idx                60552 non-null object
# startTime          60552 non-null object
# websitePageUrl     60552 non-null object
# visitTime          60552 non-null object
# engagementTime1    60552 non-null object
# pageTitle          60552 non-null object
# url                60552 non-null object
# viewportWidth      60552 non-null object
# viewportHeight     60552 non-null object
# tags1              60552 non-null object
# e                  60552 non-null object
# t                  60552 non-null object
# ta                 24886 non-null object
# ty                 60552 non-null object
# x                  60552 non-null object
# y                  60552 non-null object
# id                 60552 non-null object
# created            60552 non-null object
# lastActivity       60552 non-null object
# pages              60552 non-null object
# duration           60552 non-null object
# engagementTime2    60552 non-null object
# totalFriction      60552 non-null object
# country            60552 non-null object
# region             60552 non-null object
# city               60552 non-null object
# isp                60552 non-null object
# ip                 60552 non-null object
# lang               60552 non-null object
# userAgent          60552 non-null object
# browser            60552 non-null object
# browserVersion     60552 non-null object
# os                 60552 non-null object
# osVersion          60552 non-null object
# device             60552 non-null object
# referrer           60552 non-null object
# referrerType       60552 non-null object
# screenRes          60552 non-null object
# entryPage          60552 non-null object
# tags2              60552 non-null object
# variables          60552 non-null object
# watched            60552 non-null object
# starred            60552 non-null object
# lng                60552 non-null object
# lat                60552 non-null object
# visitorId          60552 non-null object
# gdpr               60552 non-null object
# visitorName        0 non-null object
# playbackUrl        60552 non-null object
# dtypes: object(49)
# memory usage: 22.6+ MB

# %%
os.chdir(r'C:\Users\Sellit\Desktop\BA_Coding\Data\test6')

# %%
start2=datetime.now()
json_data1 = df_test.to_json(orient = 'index')

with open('out3.json', 'w') as f:
     json.dump(json_data1, f)

end2 = datetime.now()
print(end2 - start2)
# Out:
# 0:00:14.495440

# %%
start3=datetime.now()

with open('out3.json') as json_file:
    json_data2 = json.load(json_file)
    
test_df = pd.read_json(json_data2, orient = 'index')

end3 = datetime.now()
print(end3 - start3)
# Out:
# 0:01:10.773141

# %%
test_df
# Out:
#        browser browserVersion    city country  \
# 0       Chrome  49.0.2623.112  Erfurt      de
# 1       Chrome  49.0.2623.112  Erfurt      de
# 2       Chrome  49.0.2623.112  Erfurt      de
# 3       Chrome  49.0.2623.112  Erfurt      de
# 16                75619                0  ...
# 17                75619                0  ...
# 18                75619                0  ...
# 19                75619                0  ...
# 20                75619                0  ...
# 21                75619                0  ...
# 22                75619                0  ...
# 23                75619                0  ...
# 24                75619                0  ...
# 25                75619                0  ...
# 26                75619                0  ...
# 27                75619                0  ...
# 28                75619                0  ...
# 29                75619                0  ...
# ...                 ...              ...  ...
# 306841            20598                0  ...
# 306842            20598                0  ...
# 306843            20598                0  ...
# 306844            20598                0  ...
# 306845            20598                0  ...
# 306846            20598                0  ...
# 306847            20598                0  ...
# 306848            20598                0  ...
# 306849            20598                0  ...
# 306850            20598                0  ...
# 306851            20598                0  ...
# 306852            20598                0  ...
# 306853            20598                0  ...
# 306854            20598                0  ...
# 306855            20598                0  ...
# 306856            20598                0  ...
# 306857            20598                0  ...
# 306858            20598                0  ...
# 306859            20598                0  ...
# 306860            20598                0  ...
# 306861            20598                0  ...
# 306862            20598                0  ...
# 306863            20598                0  ...
# 306864            20598                0  ...
# 306865            20598                0  ...
# 306866            20598                0  ...
# 306867            20598                0  ...
# 306868            20598                0  ...
# 306869            20598                0  ...
# 306870            20598                0  ...
#
#                                                 variables  viewportHeight  \
# 0       [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 1       [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 2       [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 3       [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 4       [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 5       [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 6       [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 7       [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 8       [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 9       [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 10      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 11      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 12      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 13      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 14      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 15      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 16      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 17      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 18      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 19      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 20      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 21      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 22      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 23      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 24      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 25      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 26      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 27      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 28      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# 29      [gclid=EAIaIQobChMI4oCkxJbB2QIVUW4bCh0PUwQBEAA...             989
# ...                                                   ...             ...
# 306841                                                 []             939
# 306842                                                 []             939
# 306843                                                 []             939
# 306844                                                 []             939
# 306845                                                 []             939
# 306846                                                 []             939
# 306847                                                 []             939
# 306848                                                 []             939
# 306849                                                 []             939
# 306850                                                 []             939
# 306851                                                 []             939
# 306852                                                 []             939
# 306853                                                 []             939
# 306854                                                 []             939
# 306855                                                 []             939
# 306856                                                 []             939
# 306857                                                 []             939
# 306858                                                 []             939
# 306859                                                 []             939
# 306860                                                 []             939
# 306861                                                 []             939
# 306862                                                 []             939
# 306863                                                 []             939
# 306864                                                 []             939
# 306865                                                 []             939
# 306866                                                 []             939
# 306867                                                 []             939
# 306868                                                 []             939
# 306869                                                 []             939
# 306870                                                 []             939
#
#        viewportWidth  visitTime                         visitorId visitorName  \
# 0               1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 1               1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 2               1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 3               1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 4               1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 5               1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 6               1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 7               1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 8               1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 9               1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 10              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 11              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 12              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 13              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 14              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 15              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 16              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 17              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 18              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 19              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 20              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 21              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 22              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 23              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 24              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 25              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 26              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 27              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 28              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# 29              1920      90359  3a87f5526dd4ec61eea93997d937e1bb         NaN
# ...              ...        ...                               ...         ...
# 306841          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306842          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306843          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306844          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306845          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306846          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306847          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306848          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306849          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306850          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306851          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306852          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306853          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306854          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306855          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306856          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306857          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306858          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306859          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306860          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306861          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306862          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306863          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306864          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306865          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306866          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306867          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306868          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306869          1920      16611  3628324a996521f37ed342da751c0284         NaN
# 306870          1920      16611  3628324a996521f37ed342da751c0284         NaN
#
#        watched                                     websitePageUrl      x  \
# 0            0                     /garten/gartenzaun/zaunpfosten   1920
# 1            0                     /garten/gartenzaun/zaunpfosten      0
# 2            0                     /garten/gartenzaun/zaunpfosten    460
# 3            0                     /garten/gartenzaun/zaunpfosten    460
# 4            0                     /garten/gartenzaun/zaunpfosten      1
# 5            0                     /garten/gartenzaun/zaunpfosten    460
# 6            0                     /garten/gartenzaun/zaunpfosten    460
# 7            0                     /garten/gartenzaun/zaunpfosten    460
# 8            0                     /garten/gartenzaun/zaunpfosten  20043
# 9            0                     /garten/gartenzaun/zaunpfosten  20392
# 10           0                     /garten/gartenzaun/zaunpfosten    461
# 11           0                     /garten/gartenzaun/zaunpfosten    486
# 12           0                     /garten/gartenzaun/zaunpfosten    681
# 13           0                     /garten/gartenzaun/zaunpfosten    681
# 14           0                     /garten/gartenzaun/zaunpfosten    681
# 15           0                     /garten/gartenzaun/zaunpfosten    681
# 16           0                     /garten/gartenzaun/zaunpfosten   2946
# 17           0                     /garten/gartenzaun/zaunpfosten   1102
# 18           0                     /garten/gartenzaun/zaunpfosten   1303
# 19           0                     /garten/gartenzaun/zaunpfosten   1552
# 20           0                     /garten/gartenzaun/zaunpfosten   1733
# 21           0                     /garten/gartenzaun/zaunpfosten   1755
# 22           0                     /garten/gartenzaun/zaunpfosten  60438
# 23           0                     /garten/gartenzaun/zaunpfosten   1754
# 24           0                     /garten/gartenzaun/zaunpfosten  62297
# 25           0                     /garten/gartenzaun/zaunpfosten   1809
# 26           0                     /garten/gartenzaun/zaunpfosten   1866
# 27           0                     /garten/gartenzaun/zaunpfosten   1790
# 28           0                     /garten/gartenzaun/zaunpfosten      0
# 29           0                     /garten/gartenzaun/zaunpfosten  61643
# ...        ...                                                ...    ...
# 306841       0  /wand-und-decke/abschlussleisten/deckenabschlu...    577
# 306842       0  /wand-und-decke/abschlussleisten/deckenabschlu...    577
# 306843       0  /wand-und-decke/abschlussleisten/deckenabschlu...  61308
# 306844       0  /wand-und-decke/abschlussleisten/deckenabschlu...    576
# 306845       0  /wand-und-decke/abschlussleisten/deckenabschlu...  60993
# 306846       0  /wand-und-decke/abschlussleisten/deckenabschlu...      0
# 306847       0  /wand-und-decke/abschlussleisten/deckenabschlu...      0
# 306848       0  /wand-und-decke/abschlussleisten/deckenabschlu...    576
# 306849       0  /wand-und-decke/abschlussleisten/deckenabschlu...    576
# 306850       0  /wand-und-decke/abschlussleisten/deckenabschlu...    576
# 306851       0  /wand-und-decke/abschlussleisten/deckenabschlu...  13237
# 306852       0  /wand-und-decke/abschlussleisten/deckenabschlu...      0
# 306853       0  /wand-und-decke/abschlussleisten/deckenabschlu...      0
# 306854       0  /wand-und-decke/abschlussleisten/deckenabschlu...      0
# 306855       0  /wand-und-decke/abschlussleisten/deckenabschlu...      0
# 306856       0  /wand-und-decke/abschlussleisten/deckenabschlu...    640
# 306857       0  /wand-und-decke/abschlussleisten/deckenabschlu...   1222
# 306858       0  /wand-und-decke/abschlussleisten/deckenabschlu...   1087
# 306859       0  /wand-und-decke/abschlussleisten/deckenabschlu...   1242
# 306860       0  /wand-und-decke/abschlussleisten/deckenabschlu...   1261
# 306861       0  /wand-und-decke/abschlussleisten/deckenabschlu...  59625
# 306862       0  /wand-und-decke/abschlussleisten/deckenabschlu...   1264
# 306863       0  /wand-und-decke/abschlussleisten/deckenabschlu...   1262
# 306864       0  /wand-und-decke/abschlussleisten/deckenabschlu...  53633
# 306865       0  /wand-und-decke/abschlussleisten/deckenabschlu...   1239
# 306866       0  /wand-und-decke/abschlussleisten/deckenabschlu...  51386
# 306867       0  /wand-und-decke/abschlussleisten/deckenabschlu...   1239
# 306868       0  /wand-und-decke/abschlussleisten/deckenabschlu...  51386
# 306869       0  /wand-und-decke/abschlussleisten/deckenabschlu...   1239
# 306870       0  /wand-und-decke/abschlussleisten/deckenabschlu...      0
#
#             y
# 0         989
# 1        4568
# 2         518
# 3         518
# 4           0
# 5         518
# 6         518
# 7         518
# 8       31018
# 9       28287
# 10        517
# 11        517
# 12        549
# 13        549
# 14        549
# 15        549
# 16      62424
# 17        624
# 18        667
# 19        727
# 20        761
# 21        759
# 22      10889
# 23        775
# 24      12209
# 25        851
# 26        931
# 27        979
# 28          0
# 29      14046
# ...       ...
# 306841    858
# 306842    852
# 306843  51051
# 306844    852
# 306845  51051
# 306846    423
# 306847    563
# 306848   1134
# 306849   1134
# 306850   1134
# 306851  14155
# 306852    704
# 306853    845
# 306854      0
# 306855   1127
# 306856   1674
# 306857  59285
# 306858   1578
# 306859   1554
# 306860   1551
# 306861  39445
# 306862   1550
# 306863   1550
# 306864  41366
# 306865   1555
# 306866  41366
# 306867   1555
# 306868  41366
# 306869   1555
# 306870      0
#
# [306871 rows x 49 columns]

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306871 entries, 0 to 306870
# Data columns (total 49 columns):
# browser            306871 non-null object
# browserVersion     306871 non-null object
# city               306871 non-null object
# country            306871 non-null object
# created            306871 non-null object
# device             306871 non-null object
# duration           306871 non-null int64
# e                  306871 non-null int64
# engagementTime1    306871 non-null int64
# engagementTime2    306871 non-null int64
# entryPage          306871 non-null object
# gdpr               306871 non-null int64
# id                 306871 non-null object
# idx                306871 non-null int64
# ip                 306871 non-null object
# isp                306871 non-null object
# lang               306871 non-null object
# lastActivity       306871 non-null object
# lat                306871 non-null float64
# lng                306871 non-null float64
# os                 306871 non-null object
# osVersion          306871 non-null object
# pageTitle          306871 non-null object
# pages              306871 non-null int64
# playbackUrl        306871 non-null object
# referrer           306871 non-null object
# referrerType       306871 non-null object
# region             306871 non-null object
# screenRes          306871 non-null object
# starred            306871 non-null int64
# startTime          306871 non-null object
# t                  306871 non-null int64
# ta                 126234 non-null object
# tags1              306871 non-null object
# tags2              306871 non-null object
# totalFriction      306871 non-null int64
# ty                 306871 non-null int64
# url                306871 non-null object
# userAgent          306871 non-null object
# variables          306871 non-null object
# viewportHeight     306871 non-null int64
# viewportWidth      306871 non-null int64
# visitTime          306871 non-null int64
# visitorId          306871 non-null object
# visitorName        0 non-null float64
# watched            306871 non-null int64
# websitePageUrl     306871 non-null object
# x                  306871 non-null int64
# y                  306871 non-null int64
# dtypes: float64(3), int64(17), object(29)
# memory usage: 117.1+ MB
