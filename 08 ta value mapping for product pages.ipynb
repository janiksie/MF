# %%
import pandas as pd
import numpy as np
import os
import json
from datetime import datetime
import re
import matplotlib.pyplot as plt

# %%
from IPython.display import display

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = 100

# %% [markdown]
# ### Load HDF5 file from working directory

# %%
os.chdir(r'C:\Users\Sellit\Desktop\BA_Coding\Data\1final_out')

# %%
start4=datetime.now()

df_purch = pd.read_hdf('utf_purchases_cat_prod_search_ta_velocity_xy_df_purch.h5', 'df_purch')

end4 = datetime.now()
print(end4 - start4)
# Out:
# 0:01:33.977404

# %%
df_purch['os'] = df_purch.os.astype('category')
df_purch['osVersion'] = df_purch.osVersion.astype('category')
df_purch['browser'] = df_purch.browser.astype('category')
df_purch['lang'] = df_purch.lang.astype('category')
df_purch['country'] = df_purch.country.astype('category')
df_purch['ty'] = df_purch.ty.astype('category')
df_purch['referrerType'] = df_purch.referrerType.astype('category')

# %% [markdown]
# ### ta value Mapping

# %%
product_page_ta_key_mapping_dict = {
'In den Warenkorb' : 'In den Warenkorb',
'sQuantity' : 'Menge',
'SwpAreaCalc_qm_input' : 'Menge',
'sSearch' : 'Suche',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > div > div > div:[2] > div > div:[3]' : 'Zubehör_Menge',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[3] > a:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li:[2]' : 'ProductDescription_Li2',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li:[3]' : 'ProductDescription_Li3',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li' : 'ProductDescription_Li',
'> div.page-wrap > section > div > div > div > div > div > div > div > div > a:[2]' : 'Thumb2',
'variant_select' : 'VariantenAuswahl',
'> div.page-wrap > section > div > div > div > div > div > div > div > div > a:[2] > img' : 'Thumb2',
'> div.page-wrap > section > div > div > div > div > header > div > h1' : 'ProductHeader_H1',
'> div.page-wrap > section > div > div > div > div > header > div > h2' : 'ProductHeader_H2',
'> div.page-wrap > section > div > div > div > div > div > div > div > div > a:[3]' : 'Thumb3',
'#hp24-accessory > div:[2] > div > div:[2] > div:[2] > div:[3] > input' : 'Zubehör_Menge',
'> div.page-wrap > section > div > div > div > div > header' : 'ProductHeader',
'> div.page-wrap > section > div > div > div > div > div > div > div:[2] > a:[2]' : 'picture_main_arrow_right',
'> div.page-wrap > section > div > div > div > div > div > div > div > div > a' : 'ThumbArea',
'> div.page-wrap > header > div > nav > ul > li:[5] > a' : 'header_Warenkorb',
'> div.page-wrap > section > div > div > div > div > div > div > div > div > a:[3] > img' : 'thumb3',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div > img' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[3]' : 'VersandInformationen',
'> div.page-wrap > header > div > div > div > a' : 'Logo',
'#hp24-accessory-add-cart-button' : 'Zubehör_InWarenkorb',
'> div.page-wrap > section > div > div > div > div:[2] > div' : 'ProductDescription',
'> div.page-wrap > header > div > nav > ul > li:[5] > a > span:[3]' : 'header_Warenkorb',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[3] > div' : 'VersandInformationen_Lieferzeit',
'> div.page-wrap > section > div > div > div > div > div > div > div > div > a > img' : 'thumbArea',
'#hp24-accessory > div:[2] > div:[3] > div:[2] > div:[2] > div:[3] > input' : 'Zubehör_Menge',
'> div.page-wrap > header > div > nav > ul > li:[2]' : 'Suche',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > a' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[3] > a' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div > div:[2] > div > div > span > span > img' : 'picture_main',
'#holabe-foobaer-muster-button' : 'Musterbestellung',
'#hp24-accessory > div:[2] > div:[2] > div:[2] > div:[2] > div:[3] > input' : 'Zubehör_Menge',
'> div.page-wrap > section > div > div > div > div > div > div > div > div > a:[4]' : 'thumb4',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li:[4]' : 'ProductDescription_Li4',
'> div.js--modal.sizing--content.no--header > div:[3]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > nav > ul > li:[5] > a' : 'Breadcrumbs',
'> div.page-wrap > header > div > nav > ul > li:[5]' : 'header_Warenkorb',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > ul > li' : 'FragenZumArtikel',
'> div.page-wrap > nav > div > div > ul > li:[2] > a' : 'MainMenu',
'> div.page-wrap > nav > div > div > ul > li:[5] > a' : 'MainMenu',
'> div.page-wrap > section > div > div > div > div:[5] > div:[2] > div > div:[2] > div > div > div' : 'AehnlicheArtikel/ZubehörToggle',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[3] > div > div > div:[2] > a' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > header > div > div' : 'Header_ArtikelMerken',
'#hp24-top-bar-container > div > p > span > a' : 'topbar',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > ul > li:[2]' : 'WeitereArtikelvonHersteller',
'> div.page-wrap > section > div > div > div > div > div > div > div > a:[2]' : 'picture_main_toggles',
'#hp24-top-bar-container > div > a' : 'topbar',
'> div.page-wrap > section > div > div > div > div > div > div > div > div:[2]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > div > div > div > div > a:[4] > img' : 'thumb4',
'> div.page-wrap > nav > div > div > ul > li:[5]' : 'MainMenu',
'> div.page-wrap > nav > div > div > ul > li:[2]' : 'MainMenu',
'#hp24-top-bar-container' : 'TopBar',
'> div.page-wrap > section > nav > ul > li:[5]' : 'Breadcrumbs',
'> div.page-wrap > nav > div > div > ul > li > a' : 'MainMenu',
'> div.page-wrap > section > nav > ul' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div > div > div > div:[2] > div > div:[6]' : 'AehnlicheArtikel/ZubehörToggle',
'> div.page-wrap > section > nav > ul > li:[7] > a' : 'Breadcrumbs',
'#hp24-accessory > div:[2] > div > div > a' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > form > div:[2] > div' : 'Stückauswahl',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[4]' : 'Länge',
'#hp24-accessory > div:[2] > div > div:[2] > div > div > a' : 'Zubehör',
'> div.page-wrap > nav > div > div > ul > li:[9] > a' : 'MainMenu',
'> div.page-wrap > nav > div > div > ul > li:[3] > a' : 'MainMenu',
'#hp24-accessory > div:[2] > div:[2] > div > a' : 'Zubehör',
'> div.page-wrap > nav > div > div > ul > li' : 'MainMenu',
'> div.page-wrap > nav > div > div > ul > li:[6] > a' : 'MainMenu',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > nav > div > div > ul > li:[4] > a' : 'MainMenu',
'> div.page-wrap > section > nav > ul > li:[3] > a' : 'Breadcrumbs',
'#hp24-top-bar' : 'TopBar',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > form' : 'Stückauswahl',
'> div.page-wrap > section > nav > ul > li:[7]' : 'Breadcrumbs',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[2] > div:[2] > div:[2] > ul > li:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > nav > div > div > ul > li:[7] > a' : 'MainMenu',
'> div.page-wrap > nav > div > div > ul > li:[9]' : 'MainMenu',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[2] > div:[2] > div:[2] > ul > li' : 'Picture_Gallery_FullScreen',
'#hp24-accessory > div:[2] > div > div:[2] > div > div > a > img' : 'Zubehör',
'> div.page-wrap > nav > div > div > ul > li:[6]' : 'MainMenu',
'> div.page-wrap > nav > div > div > ul > li:[3]' : 'MainMenu',
'> div.page-wrap > nav > div > div > ul > li:[4]' : 'MainMenu',
'> div.page-wrap > section > nav > ul > li:[3]' : 'Breadcrumbs',
'#hp24-artikel-bild-hinweis' : 'picuture_main_ArtikelBildHinweis',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > h3' : 'ProductDescription_H1',
'> div.page-wrap > section > div > div > div > div > div > div > div:[2] > div > div:[8]' : 'picture_main',
'> div.page-wrap > nav > div > div > ul > li:[7]' : 'MainMenu',
'#hp24-top-bar-container > a:[3]' : 'topbar',
'> div.page-wrap > section > nav > ul > li > a' : 'Breadcrumbs',
'> div.page-wrap > header > div > nav > ul > li:[4] > a' : 'header_MeinKonto',
'> div.page-wrap > nav > div > div > ul > li:[8] > a' : 'MainMenu',
'#hp24-accessory > div:[2] > div:[3] > div > a' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > p' : 'ProductDescription_H2',
'> div.page-wrap > section > nav > ul > li' : 'Breadcrumbs',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[3] > div > div > div:[2] > a > span > span > img' : 'Picture_Gallery_FullScreen',
'#hp24-top-bar-container > a:[2]' : 'topbar',
'#hp24-accessory > div:[2] > div:[2] > div:[2] > div > div > a' : 'Zubehör',
'> div.page-wrap > header > div > nav > ul > li:[4]' : 'header_MeinKonto',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > a:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[5]' : 'TopBeratung_Rückgaberecht',
'> div.page-wrap > header > div' : 'Header',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div > div' : 'ProductDescription_Price',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[3]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > nav > div > div > ul > li:[8]' : 'MainMenu',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[2] > div > div > div:[2] > a' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[3] > div > div > div:[2] > a:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div > div > a' : 'picture_main_toggles',
'> div.page-wrap > section > div > div > div > div > div > div > div > div > a:[5]' : 'thumb5',
'#hp24-top-bar-container > a' : 'topbar',
'> div.page-wrap > section > nav > ul > li:[6]' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div > a' : 'ProductDescription_Tab1',
'> div.page-wrap > section > div > div > div > div > div > div:[2]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[3] > div:[2] > div:[2] > a' : 'VersandInformationen_Tiefpreis',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div > div > div > div > span > span > img' : 'picture_main',
'> div.page-wrap > section > div > div > div > div > div > div > div > a:[2] > img' : 'picture_main_toggles',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[8] > td:[2]' : 'ProductDescription_table',
'> div.page-wrap > header > div > nav > ul > li:[3] > a' : 'header_Merkzettel',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[3] > div:[2] > div > a' : 'VersandInformationen_Stück',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[6] > td:[2]' : 'ProductDescription_table',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div:[2] > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > form > div > div' : 'Stückauswahl',
'#hp24-accessory-mehr-button' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[3] > div > div > p:[2] > span' : 'VersandInformationen_Lieferzeit',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > p:[2]' : 'ProductDescription',
'#Ebene_1' : 'VersandInformationen_Tiefpreis',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[5] > td:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div > a:[2]' : 'ProductDescription_Tab2',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[3] > div:[2] > a' : 'VersandInformationen_IndAngebot',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[9] > td:[2]' : 'ProductDescription_table',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[3]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > header > div > nav > ul > div:[2]' : 'header_trustLogos',
'> div.page-wrap > section > div > div > div > div > div > div > div > a:[3]' : 'picture_main_toggles',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > ul > li:[2] > a' : 'WeitereArtikelvonHersteller',
'> div.page-wrap > section > nav > ul > li:[4]' : 'Breadcrumbs',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[2] > div:[2] > div > ul > li:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > header > div > nav > ul > li:[3]' : 'header_Merkzettel',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[7] > td:[2]' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div:[2] > div:[2] > div > div > a > img' : 'Zubehör',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[2] > a' : 'ZuletztAngesehen_Element_2',
'> div.page-wrap > section > div > div > div > div > header > div > div > a' : 'productBrandLogo',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[4] > td:[2]' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div:[3] > div:[2] > div > div > a' : 'Zubehör',
'#hp24-top-bar-container > div' : 'topBar',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > ul > li > a' : 'FragenZumArtikel',
'#hp24-accessory > div:[2] > div:[4] > div:[2] > div:[2] > div:[3] > input' : 'Zubehör_Menge',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > a:[2]' : 'ProductDescription',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[2] > div > div > div:[2] > a > span > span > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div > div:[4]' : 'picture_main_toggles',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div > div > div > span > span:[3] > p > a' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div > div > div:[2] > span:[2]' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div > div > div > div > div > a:[5] > img' : 'thumb5',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[3] > a' : 'ZuletztAngesehen_Element_3',
'#hp24-accessory' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[3]' : 'WeiterführendeLinks',
'> div.page-wrap > section > div > div > div > div > div > div > div > a:[3] > img' : 'picture_main_toggles',
'> div.page-wrap > section > div > div:[2] > div:[2] > div' : 'ZuletztAngesehen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[3] > td:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > p' : 'ProductDescription',
'> div.js--modal.sizing--content.no--header > div:[2] > div' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > p > strong' : 'ProductDescription',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[2] > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > form > div:[2]' : 'ProductDescription_Price',
'mouse-out' : 'mouse-out',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[2] > a > span > span > img' : 'ZuletztAngesehen_Element_2',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div > div > div > div:[2] > a > span > span > img' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div:[3] > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[2] > td:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > nav > ul > li:[5] > a > span' : 'Breadcrumbs',
'> div.page-wrap > section > nav > ul > li:[2]' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[8]' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[11] > td:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div' : 'ProductDescription_Price',
'#hp24-accessory > div:[2] > div:[4] > div > a' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li:[5]' : 'ProductDescription',
'> div.js--modal.sizing--auto.no--header > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div > a > span > span > img' : 'ZuletztAngesehen',
'#hp24-accessory > div:[2] > div:[3] > div:[2] > div > div > a > img' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr > td:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div > a' : 'ZuletztAngesehen',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[2] > div > div > div:[2] > a:[2]' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > nav > ul > li:[7] > a > span' : 'Breadcrumbs',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div > div > div > div:[2] > a' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[2] > div:[2] > div > ul > li' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[3] > div > a:[2]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[12] > td:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[3] > a > span > span > img' : 'ZuletztAngesehen_Element_3',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[3] > div > div > div:[2] > a' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[2] > div > div > div:[2] > a' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div > div:[2] > div > div:[3] > div' : 'ProductDescription',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[4] > a' : 'ZuletztAngesehen_Element_4',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[7]' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[2] > a:[2]' : 'ZuletztAngesehen_Element_2',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[13] > td:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div > span > span > img' : 'ProductDescription_Price',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > a' : 'Picture_Gallery_FullScreen',
'#hp24-accessory > div:[2]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[3] > div > div > p' : 'VersandInformationen_Lieferzeit',
'> div.page-wrap > section > div > div > div > div > div > div > div > a > img' : 'picture_main_toggles',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[3] > a:[2]' : 'ZuletztAngesehen_Element_3',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div > div > div > div:[2] > a:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div > div > div:[2]' : 'ProductDescription_Price',
'#hp24-accessory > div:[2] > div > div:[2]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[3] > div > div > div:[2] > a:[2]' : 'Zubehör',
'#hp24-accessory > div:[2] > div:[4] > div:[2] > div > div > a' : 'Zubehör',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div:[2] > div > div:[3]' : 'ProductDescription',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[2] > div > div > div:[2] > a:[2]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div > div > div > div > a:[4]' : 'picture_main_toggles',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div > a:[2]' : 'ZuletztAngesehen',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li > a' : 'Breadcrumbs',
'#auto_preisberechnung' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[4] > div > div > div:[2] > a' : 'Zubehör',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[3] > a:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[6]' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[14] > td:[2]' : 'ProductDescription_table',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div:[6] > img' : 'Picture_Gallery_FullScreen',
'#hp24-top-bar-container > div > a > span' : 'topbar',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[15] > td:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div:[2] > div:[2] > div:[2] > div > p' : 'ProductDescription',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[4] > a:[2]' : 'ZuletztAngesehen_Element_4',
'> div.page-wrap > section > div > div > div > div > div > div > div:[4] > a:[2]' : 'picture_main_toggles',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a:[2]' : 'Picture_Gallery_FullScreen',
'#hp24-accessory > div:[2] > div:[5] > div:[2] > div:[2] > div:[3] > input' : 'Zubehör_Menge',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div > div > div > div:[2] > a' : 'Zubehör',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div:[4] > img' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[4] > a > span > span > img' : 'ZuletztAngesehen_Element_4',
'> div.page-wrap > section > div > div > div > div > div > div > div > a:[4] > img' : 'picture_main_toggles',
'#hp24-accessory-title' : 'Zubehör',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li:[2] > a' : 'Breadcrumbs',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div:[3]' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a:[3]' : 'Picture_Gallery_FullScreen',
'#hp24-accessory > div:[2] > div:[4] > div:[2] > div > div > a > img' : 'Zubehör',
'#hp24-top-bar-container > div:[2] > p > strong' : 'topbar',
'> div.page-wrap > nav > div > div > ul > li > a > span' : 'MainMenu',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div > div > div > span > span:[2]' : 'ProductDescription_Price',
'#hp24-accessory > div:[2] > div:[2] > div:[2]' : 'Zubehör',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a:[2] > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > nav > div > div > ul > li:[2] > a > span' : 'MainMenu',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[2] > div > div > div:[2] > a > span > span > img' : 'Zubehör',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[3] > div > div > div:[2] > a > span > span > img' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[3] > div > span' : 'VersandInformationen',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[4] > div > div > div:[2] > a:[2]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div > div > div > div:[2] > a:[2]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[8] > td' : 'ProductDescription_table',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[5] > a' : 'ZuletztAngesehen_Element_5',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[7] > td' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > form > div' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div > div > div > div:[2] > a > span > span > img' : 'Zubehör',
'#hp24-top-bar-container > div > p > strong' : 'topbar',
'#hp24-top-bar-container > div:[2] > p > span' : 'topbar',
'#hp24-accessory > div:[2] > div:[5] > div > a' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[6] > td' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > a' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr > td' : 'ProductDescription_table',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div:[4]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[9] > td' : 'ProductDescription_table',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[3]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[3] > div > div > p > span' : 'VersandInformationen_Lieferzeit',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div > div > div' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[4] > td' : 'ProductDescription_table',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[4] > div > div:[2] > div > div' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[16] > td:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[5] > a > span > span > img' : 'ZuletztAngesehen_Element_5',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[3] > td' : 'ProductDescription_table',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li:[3] > a' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div > div:[2] > div > div:[3] > div:[2] > div > a' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > div > div > div:[4] > a:[3]' : 'picture_main_toggles',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[2] > div:[2] > div > ul > li > a' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a:[3] > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[5] > div > div > div:[2] > a' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div > div:[2] > div > div:[3] > div > div > p:[2] > span' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[2] > td' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[4] > div > div > div:[2] > a > span > span > img' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[5] > td' : 'ProductDescription_table',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li:[2]' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div:[2] > div:[2] > div:[2] > div > ul > li > a' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div' : 'Zubehör',
'> div.page-wrap > nav > div > div > ul > li:[3] > a > span' : 'MainMenu',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[3] > div' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[5] > div > div > div:[2] > a:[2]' : 'Zubehör',
'#hp24-accessory > div:[2] > div:[3] > div:[2]' : 'Zubehör',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a:[4]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[17] > td:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div > div > div > div:[4] > a' : 'picture_main_toggles',
'#hp24-accessory > div:[2] > div:[5] > div:[2] > div > div > a' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > p:[2]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div > div > div:[2] > span:[3] > span' : 'ProductDescription_Price',
'> div.page-wrap > section > nav > ul > li:[3] > a > span' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[11] > td' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div > div:[2] > div:[2] > div:[2]' : 'Zubehör',
'> div.page-wrap > nav > div > div > ul > li:[5] > a > span' : 'MainMenu',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li:[6]' : 'ProductDescription',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li:[4] > a' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div > div:[2] > div > div:[3] > div:[2] > a' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li:[3] > strong' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[5] > div > div > div:[2] > a > span > span > img' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div:[2] > div:[2] > div:[2]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div > div > div > span > span:[3] > p' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div > div > div > div > a:[5]' : 'picture_main_toggles',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li:[3]' : 'Breadcrumbs',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[4] > div > div:[2] > div > a' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div:[2] > div:[2] > div:[2] > div:[2] > p' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li:[2] > strong' : 'ProductDescription',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div:[2] > div > div:[3] > div:[2] > div:[2] > a' : 'ProductDescription',
'> div.page-wrap > nav > div > div > ul > li:[9] > a > span' : 'MainMenu',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div:[2] > div:[2] > div:[2] > div > ul > li:[2] > a' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[3] > div > a' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[18] > td:[2]' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div > div:[2] > div:[2] > div' : 'Zubehör',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[5] > a:[2]' : 'ZuletztAngesehen_Element_5',
'> div.js--modal.sizing--auto.no--header > div:[3]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > p:[3]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > div > div > div:[4] > a:[4]' : 'picture_main_toggles',
'#hp24_accessory_form' : 'Zubehör',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div:[5] > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[12] > td' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > p:[2] > img:[2]' : 'ProductDescription',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div:[6]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > nav > div > div > ul > li:[6] > a > span' : 'MainMenu',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a:[4] > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li:[5] > a' : 'Breadcrumbs',
'#hp24-accessory > div:[2] > div:[5] > div:[2] > div > div > a > img' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div:[2] > div:[2] > div:[2] > div > ul > li' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul:[2] > li:[2]' : 'ProductDescription',
'#hp24-accessory > div:[2] > div:[6] > div:[2] > div:[2] > div:[3] > input' : 'Zubehör_Menge',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div:[2] > div:[2] > div:[2] > div:[3] > p' : 'ProductDescription',
'#hp24-accessory > div:[2] > div:[2] > div:[2] > div:[2] > div:[2]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div:[2] > div:[2] > div:[2] > p' : 'ProductDescription',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li' : 'Breadcrumbs',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li:[4]' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[16] > td:[2] > li:[5]' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div:[2] > div:[2] > div:[2] > div' : 'Zubehör',
'> div.page-wrap > section > nav > ul > li > a > span' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[13] > td' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div > div > div > div > a:[5] > img' : 'picture_main_toggles',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[14] > td' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div' : 'ProductDescription_Price',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a:[5]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[9] > td:[2] > li' : 'ProductDescription_table',
'> div.page-wrap > nav > div > div > ul > li:[7] > a > span' : 'MainMenu',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[16] > td:[2] > li:[4]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[3] > div > div > p:[2]' : 'VersandInformationen_Lieferzeit',
'> div.page-wrap > section > nav > ul > li:[5] > ul' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div:[2] > div:[2] > div:[2] > div > ul > li:[2]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > form > div:[2] > div > label' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div > div > div > span > span' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[4] > form' : 'ProductDescription_Price',
'#hp24-top-bar-container > div:[2]' : 'topbar',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[15] > td:[2] > li' : 'ProductDescription_table',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li > a' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > p:[2] > img' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[14] > td:[2] > li' : 'ProductDescription_table',
'> div.js--modal.no--header.sizing--content > div:[3]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[19] > td:[2] > li:[2]' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div:[4] > div:[2]' : 'Zubehör',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[2] > div:[2] > div:[2] > ul' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div:[2] > div > div > div > div:[2]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[2] > hr' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[19] > td:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[16] > td:[2] > li:[2]' : 'ProductDescription_table',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div:[4]' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div:[5]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li:[5]' : 'Breadcrumbs',
'> div.js--modal.sizing--auto.no--header > div:[2] > div:[2] > div:[2]' : 'Picture_Gallery_FullScreen',
'#hp24-accessory > div:[2] > div:[3] > div:[2] > div:[2] > div:[2]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li > strong' : 'ProductDescription',
'> div.page-wrap > nav > div > div > ul > li:[4] > a > span' : 'MainMenu',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[8] > td:[2] > li' : 'ProductDescription_table',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[3] > div > div > div:[2] > a > span' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[16] > td:[2] > li' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > form > div:[2] > div > div' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[17] > td:[2] > li' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div > div:[2] > div:[2] > div:[3]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[3] > div:[2]' : 'VersandInformationen_Ind_Stück_Tiefpreis',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[19] > td:[2] > li' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[14] > td:[2] > li:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[8] > td:[2] > li:[2]' : 'ProductDescription_table',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a:[5] > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[19] > td:[2] > li:[3]' : 'ProductDescription_table',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[9] > td:[2] > li:[2]' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div:[2] > div' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[3] > div:[2] > div' : 'VersandInformationen_Ind_Stück_Tiefpreis',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul:[2]' : 'ProductDescription',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[2] > div > a' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[14] > td:[2] > li:[3]' : 'ProductDescription_table',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[15] > td' : 'ProductDescription_table',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[3] > div > div > div:[2] > a' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[14] > td:[2] > li:[6]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div > a:[3]' : 'ProductDescription_Tab3',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div > div > div:[2] > span:[3]' : 'ProductDescription_Price',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[2]' : 'Breadcrumbs',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[3] > div > div > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[3]' : 'Zubehör',
'#hp24-accessory > div:[2] > div > div' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[7] > td:[2] > li' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[16] > td:[2] > li:[3]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[16] > td' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div:[6] > div > a' : 'Zubehör',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > a:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div:[2] > div > div:[3] > div > div > p' : 'ProductDescription',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[3] > a' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul:[2] > li' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[9]' : 'ProductDescription_Price',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[2] > a' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[15] > td:[2] > li:[2]' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div:[3] > div:[2] > div:[2] > div' : 'Zubehör',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a:[6]' : 'Picture_Gallery_FullScreen',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[2] > div:[2] > div:[2] > ul > li:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div > div:[4] > a:[5]' : 'picture_main_toggles',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[2]' : 'Zubehör',
'> div.page-wrap > nav > div > div > ul > li:[8] > a > span' : 'MainMenu',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[14] > td:[2] > li:[4]' : 'ProductDescription_table',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[4] > a' : 'Breadcrumbs',
'#hp24-accessory > div:[2] > div:[6] > div:[2] > div > div > a' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[17] > td' : 'ProductDescription_table',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[3] > a > span' : 'ZuletztAngesehen_Element_3',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[2] > a > span' : 'ZuletztAngesehen_Element_2',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[2] > div:[2] > div:[2] > ul > li' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[2] > div > div > div:[2] > a > span' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > h3' : 'ProductDescription',
'#hp24-accessory > div:[2] > div:[2] > div:[2] > div:[2] > div:[3]' : 'Zubehör',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a:[6] > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[14] > td:[2] > ul > li' : 'ProductDescription_table',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[3]' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li:[3] > b' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > a' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[11]' : 'ProductDescription_Price',
'#hp24-accessory > div:[2] > div:[3] > div' : 'Zubehör',
'#hp24-accessory > div:[2] > div:[8] > div:[2] > div:[2] > div:[3] > input' : 'Zubehör_Menge',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[5] > div' : 'ProductDescription_Price',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li:[7]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[19] > td:[2] > li:[4]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[8] > td:[2] > li:[3]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul:[2] > li:[3]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > div > p' : 'ProductDescription',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[3] > a' : 'Breadcrumbs',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[2] > div > div > div:[2] > div > div > div' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[11] > td:[2] > li' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[4]' : 'Zubehör',
'#hp24-accessory > div:[2] > div:[5] > div:[2]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[17] > td:[2] > li:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[8] > a' : 'Breadcrumbs',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div:[7]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div > div > div:[2] > span' : 'ProductDescription_Price',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[4]' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[14] > td:[2] > li:[5]' : 'ProductDescription_table',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[2] > div:[2] > div > ul' : 'Picture_Gallery_FullScreen',
'#hp24-accessory > div:[2] > div:[8] > div > a' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li:[2] > b' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > div > div > div:[4] > a:[6]' : 'picture_main_toggles',
'> div.js--modal.sizing--content.no--header > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[19] > td' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul:[2] > li:[6]' : 'ProductDescription',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[3] > div > div > div:[2] > div > div > div' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li:[7] > a' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div > div:[2] > div > div:[3] > div > div > p > span' : 'ProductDescription',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[5]' : 'Breadcrumbs',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div > a > span' : 'ZuletztAngesehen',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[5] > a' : 'Breadcrumbs',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[4] > div > div > div:[2] > a' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li:[6] > a' : 'Breadcrumbs',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[3] > div > div > div:[2] > a:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div:[2] > div > div:[3] > div > span' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[18] > td' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[7] > td:[2] > li:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > nav > ul > li:[5] > a > i' : 'Breadcrumbs',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[2] > div > div > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.js--modal.no--header.sizing--auto.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div > div:[4] > a:[7]' : 'picture_main_toggles',
'#hp24-accessory > div:[2] > div > div:[2] > div:[2] > div:[3] > label' : 'Zubehör',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[4] > a > span' : 'ZuletztAngesehen_Element_4',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul:[2] > li:[4]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[7] > td:[2] > li:[3]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[12] > td:[2] > li' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div:[6] > div:[2] > div > div > a > img' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[8] > td:[2] > li:[4]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[17] > td:[2] > li:[3]' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div:[7] > div > a' : 'Zubehör',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[2]' : 'Picture_Gallery_FullScreen',
'#hp24-accessory > div:[2] > div:[7] > div:[2] > div > div > a' : 'Zubehör',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[5] > div > div > div:[2] > a' : 'Picture_Gallery_FullScreen',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[2] > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[4] > div > div:[2] > div > div > div > div > div > div:[2] > a:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[16] > td:[2] > li:[6]' : 'ProductDescription_table',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[3] > div > div > div:[2] > a > span > span > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div:[2] > div:[2] > div:[2] > div' : 'ProductDescription',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div > div:[7] > img' : 'Picture_Gallery_FullScreen',
'#hp24-accessory > div:[2] > div:[3] > div:[2] > div:[2] > div:[3]' : 'Zubehör',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[4] > div > div > div:[2] > a > span > span > img' : 'Picture_Gallery_FullScreen',
'#hp24-accessory > div:[2] > div:[4] > div' : 'Zubehör',
'#hp24-accessory > div:[2] > div:[4] > div:[2] > div:[2] > div' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[3] > div > div > div:[2]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul:[2] > li:[5]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div:[3] > span > span > img' : 'VersandInformationen',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[7] > a' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[14] > td:[2] > li:[7]' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div:[4] > div:[2] > div:[2] > div:[2]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li:[4] > strong' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[7] > td:[2] > li:[4]' : 'ProductDescription_table',
'> div.page-wrap > section > nav > ul > li:[3] > ul' : 'Breadcrumbs',
'> div.js--modal.is--fullscreen.sizing--content.no--header' : 'Picture_Gallery_FullScreen',
'#hp24-accessory > div:[2] > div:[8] > div:[2] > div > div > a' : 'Zubehör',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[11] > td:[2] > li:[2]' : 'ProductDescription_table',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[2] > div > a > span > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[3] > div > div > div:[2] > div > div > div' : 'Zubehör',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[9] > a' : 'Breadcrumbs',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[5] > div > div > div:[2] > a > span > span > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > div > div > div:[2] > span:[2] > span' : 'ProductDescription_Price',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div > div:[3]' : 'Picture_Gallery_FullScreen',
'#hp24-accessory > div:[2] > div > div:[2] > div:[2]' : 'Zubehör',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[6]' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[11] > td:[2] > li:[3]' : 'ProductDescription_table',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li:[6]' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[13] > td:[2] > li' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[18] > td:[2] > li:[2]' : 'ProductDescription_table',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[3]' : 'Picture_Gallery_FullScreen',
'#hp24-accessory > div:[2] > div:[8] > div:[2] > div > div > a > img' : 'Zubehör',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[2] > div:[2] > div > ul > li:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[9] > td:[2] > li:[3]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[21] > td:[2]' : 'ProductDescription_table',
'#hp24-accessory > div:[2] > div:[7] > div:[2] > div:[2] > div:[3] > input' : 'Zubehör_Menge',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[2] > div > div > div:[2] > a' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div:[2] > div:[2] > div > div > div > div:[2] > div > div > div:[2] > a' : 'Zubehör',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[6] > div > div > div:[2] > a' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[3] > a:[2] > i' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul:[2] > li:[7]' : 'ProductDescription',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[15] > td:[2] > li:[4]' : 'ProductDescription_table',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div > div > div > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[4] > div > div' : 'Picture_Gallery_FullScreen',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[2] > div > div > div:[2] > a:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[8]' : 'Breadcrumbs',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[7]' : 'Breadcrumbs',
'> div.js--modal.sizing--content.no--header' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div > div > div > div:[2] > div > div > div' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[19] > td:[2] > li:[5]' : 'ProductDescription_table',
'> div.js--modal.is--fullscreen.sizing--content.no--header > div:[2] > div > div:[3] > a:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div:[2] > div:[2] > div > div:[2]' : 'ZuletztAngesehen_Element_2',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[7] > div > div > div:[2] > a' : 'Picture_Gallery_FullScreen',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[7] > div > div > div:[2] > a > span > span > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[22] > td:[2] > li' : 'ProductDescription_table',
'> div.page-wrap > section > nav > ul > li:[3] > ul > li:[6] > a' : 'Breadcrumbs',
'> div.js--modal.sizing--auto.no--header > div:[2] > div:[2]' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[5]' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[13] > td:[2] > li:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[2] > div > div > div:[2] > div > div > div' : 'Zubehör',
'#hp24-accessory > div:[2] > div:[7] > div:[2] > div > div > a > img' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div > div > div:[2] > div > form > div:[2] > button > i' : 'In den Warenkorb',
'#hp24-accessory > div:[2] > div:[2] > div:[2] > div:[2] > div:[3] > label' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[18] > td:[2] > li' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[21] > td:[2] > li' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[9] > td:[2] > li:[4]' : 'ProductDescription_table',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[4] > div > div:[2] > div > div > div > div > div > div:[2] > a' : 'Picture_Gallery_FullScreen',
'> div.js--modal.is--fullscreen.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > nav > ul > li:[3] > a > i' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[15] > td:[2] > li:[3]' : 'ProductDescription_table',
'> div.js--modal.sizing--content.no--header > div:[2] > div > div:[4] > div > div:[2] > div > div > div > div > div > div:[2] > a > span' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[14] > td:[2] > ul > li:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div > ul > li > b' : 'ProductDescription',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a:[7] > img' : 'Picture_Gallery_FullScreen',
'#hp24-accessory > div:[2] > div:[9] > div > a' : 'Zubehör',
'> div.page-wrap > section > div > div > div > div:[3] > div > a:[3]' : 'Zubehör',
'> div.page-wrap > section > nav > ul > li:[5] > ul > li:[7]' : 'Breadcrumbs',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div:[2] > div:[2] > div > div > div > div:[3] > div > div > div:[2] > a' : 'Zubehör',
'> div.js--modal.sizing--auto.no--header.image-gallery--modal.no--border-radius > div:[2] > div > div:[2] > div > a:[7]' : 'Picture_Gallery_FullScreen',
'> div.js--modal.no--header.sizing--content > div:[2] > div > div:[4] > div > div:[2] > div > div > div:[2] > div > div > div:[2] > a > span > span > img' : 'Picture_Gallery_FullScreen',
'> div.page-wrap > section > div > div > div > div:[2] > div:[2] > div > div:[3] > div:[2] > div:[2] > table > tbody > tr:[12] > td:[2] > li:[2]' : 'ProductDescription_table',
'> div.page-wrap > section > div > div > div > div > div > div > div > a:[6]' : 'picture_main_toggles',
'> div.page-wrap > section > div > div > div > div:[3] > div:[2] > div > div:[2] > div > div > div > div:[2] > div > div > div:[2]' : 'Zubehör'
}

# %%
def _product_ta_key_mapping(row):
    if row['page_cat'] == 'product':           
        return product_page_ta_key_mapping_dict.get(row['ta'], "not specified")

# %%
start2=datetime.now()

df_purch['ta_key_map_pr'] = df_purch.apply(_product_ta_key_mapping, axis=1)

end2 = datetime.now()
print(end2 - start2)
print(start2)
print(end2)

# %%
df_purch
# Out:
#           idx                     startTime             websitePageUrl  \
# 0           0 2018-01-20 15:46:50.740266800      /bodenbelaege/laminat
# 1           0 2018-01-20 15:46:50.740266800      /bodenbelaege/laminat
# 2           0 2018-01-20 15:46:50.740266800      /bodenbelaege/laminat
# 3           0 2018-01-20 15:46:50.740266800      /bodenbelaege/laminat
# 4           0 2018-01-20 15:46:50.740266800      /bodenbelaege/laminat
# 5           0 2018-01-20 15:46:50.740266800      /bodenbelaege/laminat
# 6           0 2018-01-20 15:46:50.740266800      /bodenbelaege/laminat
# 7           0 2018-01-20 15:46:50.740266800      /bodenbelaege/laminat
# 8           0 2018-01-20 15:46:50.740266800      /bodenbelaege/laminat
# 9           0 2018-01-20 15:46:50.740266800      /bodenbelaege/laminat
# 10          0 2018-01-20 15:46:50.740266800      /bodenbelaege/laminat
# 11          0 2018-01-20 15:46:50.740266800      /bodenbelaege/laminat
# ...

# %% [markdown]
# ### Write file and save it to working directory

# %%
df_purch['os'] = df_purch.os.astype(object)
df_purch['osVersion'] = df_purch.osVersion.astype(object)
df_purch['browser'] = df_purch.browser.astype(object)
df_purch['lang'] = df_purch.lang.astype(object)
df_purch['country'] = df_purch.country.astype(object)
df_purch['ty'] = df_purch.ty.astype(object)
df_purch['referrerType'] = df_purch.referrerType.astype(object)

# %%
start2=datetime.now()

df_purch.to_hdf('utf_purchases_ta_products_mapping_df_purch.h5', 'df_purch', mode='w')

end2 = datetime.now()
print(end2 - start2)
