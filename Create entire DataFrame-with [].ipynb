# %%
import pandas as pd
import numpy as np
import os
import json
from datetime import datetime

# %%
def _create_dataframes_from_json (json_x, idx):
    '''Return a dataframe from the json file (the idx is only important for the next function)'''

    # It is important to set the working directory to the correct path

    # Import modules
    import numpy as np
    import pandas as pd
    import json

    # Load JSON and create dictionary json_data
    with open(json_x) as json_file:
        json_data = json.load(json_file)

    # Get list of dictionaries with the corresponding x,y-pairs and time
    events_lt = json_data.get('events')

    # Create dataframe from list of dictionaries
    events_df = pd.DataFrame(events_lt)

    # Get dictionary with the information of the session
    session_dc = json_data.get('session')

    # Create dataframe from dictionary (with one row) (session data)
    session_df_temp = pd.DataFrame.from_dict(session_dc, orient ='index')
    session_df_temp = session_df_temp.transpose()

    # Create dataframe with number of rows corresponding to events_df
    session_df = session_df_temp.append([session_df_temp]*(events_df.x.count()-1),ignore_index=True)

    # Get the first rows of the json file in a dictionary
    beg_dc = dict((k, json_data[k]) for k in ('startTime', 'websitePageUrl', 'visitTime',"engagementTime", "pageTitle", "url", 
                                       "viewportWidth", "viewportHeight", "tags"))

    # Create dataframe from dictionary (with one row) (data of first rows)
    beg_df_temp = pd.DataFrame.from_dict(beg_dc, orient = 'index').T

    # Create dataframe with number of rows corresponding to events_df
    beg_df = beg_df_temp.append([beg_df_temp]*(events_df.x.count()-1),ignore_index=True)

    # Concatenate all three dataframes into one
    df = pd.concat([ beg_df, events_df, session_df],axis=1)
    
    # Add index column (for further function)
    df.insert(loc=0,column='idx', value = idx)
    
    # Check if 'ta' column exists
    if 'ta' not in df.columns:
        df.insert(loc=12,column='ta', value = np.NaN)
        
    # Check if 'v' column exists
    if 'v' in df.columns:
        del df['v']

    # Return dataframe
    return df

# %%
def _create_dataframe_from_files(work_dir):
    '''This function takes the working directory as an input, uses the function '_create_dataframes_from_json' to 
    transform the json files into dataframes and returns a 'big' dataframe where the single dataframes of each file 
    are concatenated'''
    
    # Return list of files in working directory
    list_dir = os.listdir(work_dir)
    
    # Initialize dataframe with all files
    df_total = pd.DataFrame(columns=['idx', 'startTime', 'websitePageUrl', 'visitTime', 'engagementTime',
       'pageTitle', 'url', 'viewportWidth', 'viewportHeight', 'tags', 'e', 't',
       'ta', 'ty', 'x', 'y', 'id', 'created', 'lastActivity', 'pages',
       'duration', 'engagementTime', 'totalFriction', 'country', 'region',
       'city', 'isp', 'ip', 'lang', 'userAgent', 'browser', 'browserVersion',
       'os', 'osVersion', 'device', 'referrer', 'referrerType', 'screenRes',
       'entryPage', 'tags', 'variables', 'watched', 'starred', 'lng', 'lat',
       'visitorId', 'gdpr', 'visitorName', 'playbackUrl'])
    
    # Loop over every file in the list and return as a dataframe
    for index, file in enumerate(list_dir):
        df_single = _create_dataframes_from_json(file,index)
        
        # Append dataframe of a single file to the dataframe with all files
        df_total = df_total.append(df_single, ignore_index = True)
        
    # Set the index to idx and t & sort index
    df_total = df_total.set_index(['idx', 't'])
    df_total = df_total.sort_index()
    
    # Return dataframe
    return(df_total)

# %%
direction = r'C:\Users\Sellit\Desktop\BA_Coding\Data\test2'

# %%
os.chdir(direction)

# %%
start=datetime.now()
df_test = _create_dataframe_from_files(direction)
end = datetime.now()
print(end - start)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-24-c1303f878656> in <module>()
#       1 start=datetime.now()
# ----> 2 df_test = _create_dataframe_from_files(direction)
#       3 end = datetime.now()
#       4 print(end - start)
#
# <ipython-input-21-7a9d4e5ef252> in _create_dataframe_from_files(work_dir)
#      19     # Loop over every file in the list and return as a dataframe
#      20     for index, file in enumerate(list_dir):
# ---> 21         df_single = _create_dataframes_from_json(file,index)
#      22
#      23         # Append dataframe of a single file to the dataframe with all files
#
# <ipython-input-20-2b2a29079bab> in _create_dataframes_from_json(json_x, idx)
#      11     # Load JSON and create dictionary json_data
#      12     with open(json_x) as json_file:
# ---> 13         json_data = json.load(json_file)
#      14
#      15     # Get list of dictionaries with the corresponding x,y-pairs and time
#
# ~\Anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
# --> 299         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     300
#     301
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2052 entries, (0, 114) to (11, 25922)
# Data columns (total 47 columns):
# startTime         2052 non-null object
# websitePageUrl    2052 non-null object
# visitTime         2052 non-null object
# engagementTime    2052 non-null object
# pageTitle         2052 non-null object
# url               2052 non-null object
# viewportWidth     2052 non-null object
# viewportHeight    2052 non-null object
# tags              2052 non-null object
# e                 2052 non-null object
# ta                771 non-null object
# ty                2052 non-null object
# x                 2052 non-null object
# y                 2052 non-null object
# id                2052 non-null object
# created           2052 non-null object
# lastActivity      2052 non-null object
# pages             2052 non-null object
# duration          2052 non-null object
# engagementTime    2052 non-null object
# totalFriction     2052 non-null object
# country           2052 non-null object
# region            2052 non-null object
# city              2052 non-null object
# isp               2052 non-null object
# ip                2052 non-null object
# lang              2052 non-null object
# userAgent         2052 non-null object
# browser           2052 non-null object
# browserVersion    2052 non-null object
# os                2052 non-null object
# osVersion         2052 non-null object
# device            2052 non-null object
# referrer          2052 non-null object
# referrerType      2052 non-null object
# screenRes         2052 non-null object
# entryPage         2052 non-null object
# tags              2052 non-null object
# variables         2052 non-null object
# watched           2052 non-null object
# starred           2052 non-null object
# lng               2052 non-null object
# lat               2052 non-null object
# visitorId         2052 non-null object
# gdpr              2052 non-null object
# visitorName       0 non-null object
# playbackUrl       2052 non-null object
# dtypes: object(47)
# memory usage: 774.5+ KB

# %%
df_test
# Out:
#                               startTime      websitePageUrl visitTime  \
# idx t
# 0   114    2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     250    2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     728    2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     797    2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     799    2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     826    2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     896    2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     958    2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     976    2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     1046   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     1211   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     1278   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     1347   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     1427   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     1428   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     1443   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     1447   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     1447   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     1449   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     3629   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     3725   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     3918   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     3940   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     3992   2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     10001  2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     11522  2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     11616  2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     11658  2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     12007  2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
#     12106  2018-06-21T11:39:06.6496909Z  /garten/gartenhaus     42596
# ...                                 ...                 ...       ...
# 11  16826  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     16839  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     16916  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     17089  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     18816  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     18839  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     19016  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     19089  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     19116  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     19226  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     19316  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     19349  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     19416  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     20006  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     20218  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     20318  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     20351  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     20408  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     20508  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     20591  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     20619  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     25341  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     25409  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     25518  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     25591  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     25608  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     25675  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     25802  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     25816  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#     25922  2018-06-21T11:46:21.5719892Z  /garten/gartenhaus     25922
#
#           engagementTime                                        pageTitle  \
# idx t
# 0   114            38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     250            38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     728            38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     797            38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     799            38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     826            38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     896            38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     958            38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     976            38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     1046           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     1211           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     1278           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     1347           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     1427           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     1428           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     1443           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     1447           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     1447           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     1449           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     3629           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     3725           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     3918           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     3940           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     3992           38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     10001          38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     11522          38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     11616          38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     11658          38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     12007          38956  Gartenhaus online kaufen | Garten | Holzprofi24
#     12106          38956  Gartenhaus online kaufen | Garten | Holzprofi24
# ...                  ...                                              ...
# 11  16826          25922  Gartenhaus online kaufen | Garten | Holzprofi24
#     16839          25922  Gartenhaus online kaufen | Garten | Holzprofi24
#     16916          25922  Gartenhaus online kaufen | Garten | Holzprofi24
#     17089          25922  Gartenhaus online kaufen | Garten | Holzprofi24
#     18816          25922  Gartenhaus online kaufen | Garten | Holzprofi24
#     18839          25922  Gartenhaus online kaufen | Garten | Holzprofi24
#     19016          25922  Gartenhaus online kaufen | Garten | Holzprofi24
#
#     1443                         ...                           []
#     1447                         ...                           []
#     1447                         ...                           []
#     1449                         ...                           []
#     3629                         ...                           []
#     3725                         ...                           []
#     3918                         ...                           []
#     3940                         ...                           []
#     3992                         ...                           []
#     10001                        ...                           []
#     11522                        ...                           []
#     11616                        ...                           []
#     11658                        ...                           []
#     12007                        ...                           []
#     12106                        ...                           []
# ...                              ...                          ...
# 11  16826                        ...                           []
#     16839                        ...                           []
#     16916                        ...                           []
#     17089                        ...                           []
#     18816                        ...                           []
#     18839                        ...                           []
#     19016                        ...                           []
#     19089                        ...                           []
#     19116                        ...                           []
#     19226                        ...                           []
#     19316                        ...                           []
#     19349                        ...                           []
#     19416                        ...                           []
#     20006                        ...                           []
#     20218                        ...                           []
#     20318                        ...                           []
#     20351                        ...                           []
#     20408                        ...                           []
#     20508                        ...                           []
#     20591                        ...                           []
#     20619                        ...                           []
#     25341                        ...                           []
#     25409                        ...                           []
#     25518                        ...                           []
#     25591                        ...                           []
#     25608                        ...                           []
#     25675                        ...                           []
#     25802                        ...                           []
#     25816                        ...                           []
#     25922                        ...                           []
#
#                                                    variables watched starred  \
# idx t
# 0   114    [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     250    [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     728    [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     797    [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     799    [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     826    [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     896    [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     958    [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     976    [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     1046   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     1211   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     1278   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     1347   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     1427   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     1428   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     1443   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     1447   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     1447   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     1449   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     3629   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     3725   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     3918   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     3940   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     3992   [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     10001  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     11522  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     11616  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     11658  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     12007  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     12106  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
# ...                                                      ...     ...     ...
# 11  16826  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     16839  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     16916  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     17089  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     18816  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     18839  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     19016  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     19089  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     19116  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     19226  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     19316  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     19349  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     19416  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     20006  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     20218  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     20318  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     20351  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     20408  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     20508  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     20591  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     20619  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     25341  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     25409  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     25518  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     25591  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     25608  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     25675  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     25802  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     25816  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#     25922  [gclid=EAIaIQobChMItf64ttXk2wIVyYXVCh2XegUVEAA...   False   False
#
#                lng      lat                         visitorId   gdpr  \
# idx t
# 0   114    53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     250    53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     728    53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     797    53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     799    53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     826    53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     896    53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     958    53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     976    53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     1046   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     1211   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     1278   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     1347   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     1427   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     1428   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     1443   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     1447   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     1447   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     1449   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     3629   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     3725   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     3918   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     3940   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     3992   53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     10001  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     11522  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     11616  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     11658  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     12007  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     12106  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
# ...            ...      ...                               ...    ...
# 11  16826  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     16839  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     16916  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     17089  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     18816  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     18839  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     19016  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     19089  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     19116  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     19226  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     19316  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     19349  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     19416  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     20006  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     20218  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     20318  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     20351  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     20408  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     20508  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     20591  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     20619  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     25341  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     25409  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     25518  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     25591  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     25608  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     25675  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     25802  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     25816  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#     25922  53.2412  53.2412  bccb3feca8cd4414eca449dc7e7af77b  False
#
#           visitorName                                        playbackUrl
# idx t
# 0   114          None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     250          None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     728          None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     797          None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     799          None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     826          None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     896          None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     958          None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     976          None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     1046         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     1211         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     1278         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     1347         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     1427         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     1428         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     1443         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     1447         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     1447         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     1449         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     3629         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     3725         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     3918         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     3940         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     3992         None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     10001        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     11522        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     11616        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     11658        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     12007        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     12106        None  https://eu.mouseflow.com/websites/4320374e-0cd...
# ...               ...                                                ...
# 11  16826        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     16839        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     16916        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     17089        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     18816        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     18839        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     19016        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     19089        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     19116        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     19226        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     19316        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     19349        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     19416        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     20006        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     20218        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     20318        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     20351        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     20408        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     20508        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     20591        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     20619        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     25341        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     25409        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     25518        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     25591        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     25608        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     25675        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     25802        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     25816        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#     25922        None  https://eu.mouseflow.com/websites/4320374e-0cd...
#
# [2052 rows x 47 columns]
